# %% [markdown]
# # Tutorial 3: Connecting to Your Data Source

# %%
import ponder.bigquery
import modin.pandas as pd
import json; import os; os.chdir("..")
creds = json.load(open(os.path.expanduser("credential.json")))
bigquery_con = ponder.bigquery.connect(creds, schema = "TEST")
ponder.bigquery.init(bigquery_con)
# Out:
# 2023-03-22 21:02:30,149 - INFO - Establishing connection to pushdown.ponder-internal.io
# Connected to
#        ___               __
#       / _ \___  ___  ___/ /__ ____
#      / ___/ _ \/ _ \/ _  / -_) __/
#     /_/___\___/_//_/\_,_/\__/_/
#       / __/__ _____  _____ ____
#      _\ \/ -_) __/ |/ / -_) __/
#     /___/\__/_/  |___/\__/_/

# %% [markdown]
# Before we start can start our analysis, we need to first connect to a data source. Ponder currently supports `read_csv` for operating on CSV files and `read_sql` for operating on tables that are already stored in BigQuery.

# %% [markdown]
# ## ``read_sql:``Working with existing tables
#
# To work with data stored in an existing table in BigQuery, we use the ``read_sql`` command and provide the name of the table ``PONDER_CUSTOMER`` and pass in ``auto`` to the connection parameter to auto-populate the connection information based on what we provided earlier

# %%
df = pd.read_sql("PONDER_CUSTOMER", bigquery_con)

# %% [markdown]
# Now that we have a Ponder DataFrame that points to the ``PONDER_CUSTOMER`` table in your data warehouse, you can now work on your DataFrame ``df`` just like you would typically do with any pandas dataframe – with all the computation happening on your warehouse!

# %%
df
# Out:
#     C_CUSTKEY              C_NAME                              C_ADDRESS  \
# 0       60082  Customer#000060082    x3V6vEbLSeUjYdjS1MvR2,u4gB0S 9d8UEJ
# 1       60080  Customer#000060080      g7cKdEj2mzUQLSKFFnWsmL,3GaOIrBmfi
# 2       60018  Customer#000060018                  lQ8PB9FGW53C36XQX2uq0
# 3       60062  Customer#000060062        1SI,x4F9 zO22 F7OGksMBSUWu5AUpP
# 4       60022  Customer#000060022              I2XoZQLC,63R3zIG z6i3VMCS
# ..        ...                 ...                                    ...
# 95      60058  Customer#000060058                             X9NS,0Ddki
# 96      60079  Customer#000060079                dwwsJWhDr0fnRJnyhe6gtls
# 97      60059  Customer#000060059  dZISBokE9NWaz13 b5WbOHrd8DifA,e2yict0
# 98      60033  Customer#000060033                            fwvb5ua8ZcB
# 99      60027  Customer#000060027                  U,Y EKzklGgxO9HK4uT2g
#
#     C_NATIONKEY          C_PHONE  C_ACCTBAL C_MKTSEGMENT  \
# 0             0  10-729-863-1818    3645.47     BUILDING
# 1             0  10-192-161-6631     689.24     BUILDING
# 2             0  10-310-354-8579    5759.83     BUILDING
# 3             0  10-604-525-3386    6210.99    FURNITURE
# 4             0  10-513-498-1045    -759.74    FURNITURE
# ..          ...              ...        ...          ...
# 95           23  33-146-680-6559    6672.12    MACHINERY
# 96           24  34-197-192-3607    3329.55     BUILDING
# 97           24  34-348-323-9173    2337.46    HOUSEHOLD
# 98           24  34-142-708-2404    -493.59    MACHINERY
# 99           24  34-250-415-3801    6115.22    MACHINERY
#
#                                             C_COMMENT
# 0                     the accounts. furiously unusual
# 1    slyly pending, permanent packages. special fo...
# 2   ckly bold deposits. carefully bold accounts in...
# 3         ons cajole blithely. bold theodolites along
# 4    across the blithely ironic sentiments. thinly...
# ..                                                ...
# 95           ess requests. special requests wake blit
# 96  ly special somas poach carefully. furiously un...
# 97  ndencies. excuses sleep. quickly daring dugout...
# 98  lithely final packages. quickly regular reques...
# 99  s. ironic packages are carefully slyly unusual...
#
# [100 rows x 8 columns]

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>Note: </b> <span> Unlike in pandas, the data ingestion (read_*) command in Ponder does not actually load in the data into a dataframe in memory. Instead, you can think of the Ponder DataFrame acting as a pointer to the table in BigQuery that stores the data and relays all the operations to be performed on the tables in BigQuery. </span></div>

# %% [markdown]
# ## ``read_csv:`` Working with CSV files

# %% [markdown]
# ### Working with remote CSV files
# To work with ``CSV`` files, use the ``read_csv`` command to feed in the filepath to the CSV file. If the filepath is a remote path to the CSV (e.g., filepath to S3, GCS, or a public dataset URL), you can enter the path directly as follow. Ponder will automatically process your CSV file and load it into a temporary table in your data warehouse account for analysis.

# %%
df = pd.read_csv("https://github.com/ponder-org/ponder-datasets/blob/main/tpch/orders.csv?raw=True", header=0)
# Out:
# 2023-03-22 21:02:48,447 - INFO - Determining schema for file
# 2023-03-22 21:02:48,758 - INFO - Finished determining schema for file
# Creating table in BigQuery...
# Finished creating table in BigQuery...
# Finished loading data into BigQuery.
# Dataframe loading complete.

# %% [markdown]
# Now that your data is loaded into a temporary table in your data warehouse and Ponder DataFrame is pointing to the table, you can now work on your DataFrame ``df`` just like you would typically do with any pandas dataframe – with all the computation happening on your warehouse!

# %%
df
# Out:
#      O_ORDERKEY  O_CUSTKEY O_ORDERSTATUS  O_TOTALPRICE O_ORDERDATE  \
# 0        603014      60040             O     102891.88   2/15/1998
# 1        611105      60011             F      85107.80   6/28/1992
# 2        612353      60085             O     174365.24    9/3/1997
# 3        613283      60002             F      81616.21   10/6/1992
# 4        617699      60022             F     253288.15   10/6/1994
# ..          ...        ...           ...           ...         ...
# 140      242343      60067             O     130940.07   2/24/1996
# 141      242722      60064             F      82821.03    4/7/1992
# 142      243297      60085             O     279667.51   7/16/1997
# 143      244579      60085             P     159397.20   6/11/1995
# 144      246241      60028             F      19117.05   5/30/1992
#
#      O_ORDERPRIORITY          O_CLERK  O_SHIPPRIORITY  \
# 0              5-LOW  Clerk#000000337               0
# 1             2-HIGH  Clerk#000000423               0
# 2              5-LOW  Clerk#000000685               0
# 3             2-HIGH  Clerk#000000298               0
# 4              5-LOW  Clerk#000000421               0
# ..               ...              ...             ...
# 140         1-URGENT  Clerk#000000792               0
# 141            5-LOW  Clerk#000000514               0
# 142  4-NOT SPECIFIED  Clerk#000000985               0
# 143  4-NOT SPECIFIED  Clerk#000000404               0
# 144            5-LOW  Clerk#000000711               0
#
#                                              O_COMMENT
# 0    egular theodolites. always special ideas sleep...
# 1                              platelets; dependencies
# 2    g pending pinto beans according to the deposit...
# 3    ly unusual requests wake furiously atop the pa...
# 4    ly express excuses sleep furiously packages. s...
# ..                                                 ...
# 140                    ackages haggle fluffily against
# 141                            according to the silent
# 142                      . regularly special packages
# 143  realms haggle blithely slyly permanent ideas. ...
# 144                      ly among the quickly silent p
#
# [145 rows x 9 columns]

# %% [markdown]
# ### Working with your own local CSV files

# %% [markdown]
# If you have a CSV file locally that you want to analyze with Ponder, we provide an interface that allows you to stage the file for analysis.
#
# **1. Uploading to Ponder:** If you have a CSV file on your local machine, you must first upload them through the notebook interface. You can upload files to your Jupyter directory using the file upload functionality provided by Jupyter notebook.
#
# <img src="https://docs.ponder.io/_images/upload2.png" width="50%"></img>
#
# **2. Staging CSV file to a remote path:** After uploading your files to the Jupyter directory, you will need to stage the file to a remote path so that it is accessible by read_csv, as following:

# %%
# !wget -q "https://raw.githubusercontent.com/ponder-org/ponder-datasets/main/tpch/supplier.csv"

# %%
from ponder.utils.core import Teleporter
t = Teleporter()
remote_path = t.depulso("supplier.csv")
# Out:
# 2023-03-22 21:03:00,979 - depulso - INFO - Compression took 0.0036573410034179688s
# 2023-03-22 21:03:00,985 - depulso - INFO - Establishing connection to remot host
# 2023-03-22 21:03:00,995 - depulso - INFO - Connection to remote host establised
# 2023-03-22 21:03:01,832 - depulso - INFO - Transfer took 0.8470602035522461s

# %% [markdown]
# **3. Read your CSV file with ``read_csv``**: Once the file is staged to the remote_path, you can load it in via `pd.read_csv` as usual.

# %%
df = pd.read_csv(remote_path, header=0)
# Out:
# 2023-03-22 21:03:02,228 - INFO - Determining schema for file
# 2023-03-22 21:03:02,270 - INFO - Finished determining schema for file
# Creating table in BigQuery...
# Finished creating table in BigQuery...
# Finished loading data into BigQuery.
# Dataframe loading complete.

# %%
df
# Out:
#       S_SUPPKEY              S_NAME                                S_ADDRESS  \
# 0             2  Supplier#000000002                    89eJ5ksX3ImxJQBvxObC,
# 1             3  Supplier#000000003        q1,G3Pj6OjIuUYfUoH18BFTKP5aU9bEV3
# 2             4  Supplier#000000004                Bk7ah4CK8SYQTepEmvMkkgMwg
# 3             6  Supplier#000000006                             tQxuVm7s7CnK
# 4             8  Supplier#000000008           9Sq4bBH2FQEmaFOocY45sRTxo6yuoG
# ...         ...                 ...                                      ...
# 3250       1982  Supplier#000001982  q5g5cl4V2Ssk6vsVTtPFBo8lT8gLcQrbojDyGsN
# 3251       1985  Supplier#000001985               iNpX5StxnUW8DlgToWvv9kZ Uk
# 3252       1986  Supplier#000001986                      D2d8InHEo5MjZHcD,Ru
# 3253       1990  Supplier#000001990    DSDJkCgBJzuPg1yuM,CUdLnsRliOxkkHezTCA
# 3254       1999  Supplier#000001999         iMJGJ97d7uZ6d4R7HueaELdtwiuv8oTO
#
#       S_NATIONKEY          S_PHONE  S_ACCTBAL  \
# 0               5  15-679-861-2259    4032.68
# 1               1  11-383-516-1199    4192.40
# 2              15  25-843-787-7479    4641.08
# 3              14  24-696-997-4969    1365.79
# 4              17  27-498-742-3860    7627.85
# ...           ...              ...        ...
# 3250           14  24-307-672-7764    2518.95
# 3251           24  34-968-184-3570    9542.91
# 3252            9  19-165-166-7955    5721.91
# 3253            3  13-430-427-6190     204.32
# 3254           21  31-410-167-3442      80.88
#
#                                               S_COMMENT
# 0                slyly bold instructions. idle dependen
# 1     blithely silent requests after the express dep...
# 2                   riously even requests above the exp
# 3     final accounts. regular dolphins use against t...
# 4                      al pinto beans. asymptotes haggl
# ...                                                 ...
# 3250  ss accounts. furiously bold accounts affix sly...
# 3251           sly regular dependencies against the bli
# 3252   regular deposits wake at the silent asymptote...
# 3253  instructions use at the quickly regular packag...
# 3254  nstructions cajole blithely bold requests. sly...
#
# [3255 rows x 7 columns]
