# %% [markdown]
# # 5-min Quickstart Guide to Ponder
# Follow along this notebook or [watch a video](https://www.youtube.com/watch?v=StA8zv607fk) to see how you can use Ponder today!

# %% [markdown]
# **What is Ponder?** Ponder lets you run your data science workflows (pandas, NumPy) directly in your database, be it Snowflake, BigQuery, or BigQuery. With Ponder, you get the same Python experience you love, but with the power and scalability of data warehouses. Learn more about Ponder [here](https://ponder.io/ponder-in-public-beta-data-science-in-your-data-warehouse/).

# %% [markdown]
# ## Step 0: Create an Account
#
# Before we get started, you first need a Ponder account.
# If you don't already have a Ponder account, you can create a free account by signing up [here](https://app.ponder.io/signup).

# %% [markdown]
# ## Step 1: Setting up Ponder

# %% [markdown]
# You can use Ponder by simply installing Ponder as a library on your own machine. With this flexible and lightweight approach, you can continue using Ponder within your own environment with your existing notebook/IDE setup.
#
# To install the library, run the following command:

# %%
# !pip install "ponder[bigquery]" # Install Ponder dependencies and BigQuery connector

# %% [markdown]
# ## Step 2: Initialize Ponder and Authenticate

# %% [markdown]
# Now we are ready to start using Ponder! To get started, you first need to initialize Ponder.

# %% [markdown]
# You will need to register your product key. Your product key can be found in your [Account Settings](https://app.ponder.io/account-settings) after you sign up for an account (following Step 0).
#
# <img src="https://docs.ponder.io/_images/api_token.png" width="60%"></img>

# %%
import ponder
ponder.init(api_key="<Enter-Your-Product-Key-Here>")

# %% [markdown]
# If you are setting up Ponder on your own machine and prefer to go through a one time setup process, check out the instructions [here](https://docs.ponder.io/getting_started/quickstart.html#step-2-login-to-authenticate). After the setup, you can run the following command to initialize Ponder.

# %%
import ponder
ponder.init()

# %% [markdown]
# ## Step 3: Connect to a Database

# %% [markdown]
# Next, configure your connection to BigQuery.

# %% [markdown]
# To establish a connection to BigQuery, we leverage Google Cloud’s [Python client for Google BigQuery](https://cloud.google.com/python/docs/reference/bigquery/latest/index.html).

# %%
from google.cloud import bigquery
from google.cloud.bigquery import dbapi
from google.oauth2 import service_account

import json

db_con = dbapi.Connection(
            bigquery.Client(
               credentials=service_account.Credentials.from_service_account_info(
                  json.loads(open("../credential.json").read()),
                  scopes=["https://www.googleapis.com/auth/bigquery"]
               )
            )
         )

# %% [markdown]
# If you are looking for more information about how to set up the connection, please check out [this guide](https://docs.ponder.io/getting_started/connection.html) for more information.

# %% [markdown]
# ## Step 4: Selecting Your Data Source

# %% [markdown]
# Ponder currently supports `read_csv`, `read_parquet` for operating on CSV, Parquet files and `read_sql` for operating on tables that are already stored in BigQuery.
# Going beyond ``read_sql``, we need to configure Ponder to leverage the BigQuery connection that we established earlier.

# %%
ponder.configure(default_connection=db_con, bigquery_dataset="TEST")

# %% [markdown]
# Then, we can use the ``read_csv`` command to feed in the file path to the CSV file.

# %%
import modin.pandas as pd

df = pd.read_csv("https://github.com/ponder-org/ponder-datasets/blob/main/books.csv?raw=True")

# %% [markdown]
# Below you can see that your CSV data is loaded into a temporary table in BigQuery, you can now work on your DataFrame ``df`` just like you would typically do with any pandas dataframe – with all the computation happening on BigQuery!

# %% [markdown]
# Now we can start hacking away with pandas! Note that every single operations you are doing here with pandas is directly being run on your database!

# %% [markdown]
# First, let's take a look at the basic statistics around the numerical columns in our dataset.

# %%
df.describe()
# Out:
#              bookID  average_rating        isbn13     num_pages  \
# count  11123.000000    11123.000000  1.112300e+04  11123.000000
# mean   21310.856963        3.934075  9.759880e+12    336.405556
# std    13094.727252        0.350485  4.429758e+11    241.152626
# min        1.000000        0.000000  8.987060e+09      0.000000
# 25%    10277.500000        3.770000  9.780345e+12    192.000000
# 50%    20287.000000        3.960000  9.780582e+12    299.000000
# 75%    32104.500000        4.140000  9.780872e+12    416.000000
# max    45641.000000        5.000000  9.790008e+12   6576.000000
#
#        ratings_count  text_reviews_count
# count   1.112300e+04        11123.000000
# mean    1.794285e+04          542.048099
# std     1.124992e+05         2576.619589
# min     0.000000e+00            0.000000
# 25%     1.040000e+02            9.000000
# 50%     7.450000e+02           47.000000
# 75%     5.000500e+03          238.000000
# max     4.597666e+06        94265.000000

# %% [markdown]
# Let's say we want to normalize the numerical columns by doing a standard z-score normalization (where $\mu$ is the mean and $\sigma$ is the standard deviation).
#
# $$ x' = \frac{x-\mu}{\sigma}$$

# %%
x = df.select_dtypes(include='number').columns
(df[x] - df[x].mean())/df[x].std()
# Out:
#          bookID  average_rating    isbn13  num_pages  ratings_count  \
# 0     -1.627362        1.814412  0.046412   1.308692      18.469003
# 1     -1.627285        1.586157  0.046411   2.212684      18.979913
# 2     -1.627133        1.386434  0.046412   0.064666      -0.103199
# 3     -1.627056        1.785880  0.046412   0.408847      20.636974
# 4     -1.626827        2.413581  0.046412   9.759771       0.208758
# ...         ...             ...       ...        ...            ...
# 11118  1.857247        0.359287  0.048942   0.728147      -0.158107
# 11119  1.857400        0.416350  0.045736   1.238197      -0.152533
# 11120  1.857476        0.073968  0.045736   0.325912      -0.152204
# 11121  1.857858       -0.610797  0.045557   0.404700      -0.152658
# 11122  1.858011       -0.068691  0.064603  -0.267074      -0.158489
#
#        text_reviews_count
# 0               10.497845
# 1               11.130456
# 2               -0.115674
# 3               13.887557
# 4               -0.146723
# ...                   ...
# 11118           -0.202610
# 11119           -0.188638
# 11120           -0.173502
# 11121           -0.156425
# 11122           -0.205715
#
# [11123 rows x 6 columns]

# %% [markdown]
# Next, let's look at all the columns that are non-numerical:

# %%
df.select_dtypes(include='object').head()
# Out:
#                                                title  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...
# 1  Harry Potter and the Order of the Phoenix (Har...
# 2  Harry Potter and the Chamber of Secrets (Harry...
# 3  Harry Potter and the Prisoner of Azkaban (Harr...
# 4  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors        isbn language_code publication_date  \
# 0  J.K. Rowling/Mary GrandPré  0439785960           eng        9/16/2006
# 1  J.K. Rowling/Mary GrandPré  0439358078           eng         9/1/2004
# 2                J.K. Rowling  0439554896           eng        11/1/2003
# 3  J.K. Rowling/Mary GrandPré  043965548X           eng         5/1/2004
# 4  J.K. Rowling/Mary GrandPré  0439682584           eng        9/13/2004
#
#          publisher
# 0  Scholastic Inc.
# 1  Scholastic Inc.
# 2       Scholastic
# 3  Scholastic Inc.
# 4       Scholastic

# %% [markdown]
# Filter to all the books that are written by J.R.R Tolkien.

# %%
df[df.authors.str.contains('J.R.R. Tolkien')]
# Out:
#       bookID                                              title  \
# 1700                  43         9/1/2003             Large Print Press
# 1701                 329        9/17/2007                 HarperCollins
# 2027                 767       11/15/2004                 Mariner Books
# 2028                4750       11/15/2004      Houghton Mifflin Company
# 2030                 145       11/12/1986                       Del Rey
# 2032                  78         5/2/2006                 HarperCollins
# 2033                  31        10/2/2003     Houghton Mifflin Harcourt
# 2035                   5         2/4/2002                 HarperCollins
# 2038                 203         6/1/1992      Del Rey/Ballantine Books
# 2039                  97         2/5/2001  HarperCollins Publishers Ltd
# 2042                  16        2/22/2002          Recorded Books  Inc.
# 4254                5798         9/5/2003              Houghton Mifflin
# 4255                   5        11/6/2003  HarperCollins Publishers Ltd
# 4261                   0       12/20/2001                  聯經出版事業股份有限公司
# 4263                  74         6/1/2005                 Mariner Books
# 4268                   0       12/20/2001                  聯經出版事業股份有限公司
# 4270                   3         3/4/2002            BBC Audiobooks Ltd
# 4271                 121         6/1/2004      Houghton Mifflin Company
# 4272                   5        10/7/2002       Collins Modern Classics
# 4274                  92         9/1/2000              Houghton Mifflin
# 4275                   2        10/8/2001                        Pocket
# 4276                   0        10/6/2003                BBC Audiobooks
# 4277                  10         1/1/2001   Quality Paperback Book Club
# 4283                   5       10/10/1999              Houghton Mifflin
# 4597                  14        10/1/1992              Houghton Mifflin
# 4644                  70        6/30/1999     Houghton Mifflin Harcourt
# 5254                  44       12/14/1993     Houghton Mifflin Harcourt
# 5255                  15        12/6/1994     Houghton Mifflin Harcourt
# 5256                  40         2/7/1999                 HarperCollins
# 5258                  44        3/12/1979              Unwin Paperbacks
# 6256                  32       10/18/2000                 Mariner Books
# 6258                 225        4/17/2007     Houghton Mifflin Harcourt
# 6261                  41       10/27/1992     Houghton Mifflin Harcourt
# 6263                 162         9/2/2002      HarperCollins Publishers
# 6265                 413         9/2/2002      HarperCollins Publishers
# 6266                   3         8/5/2002                 HarperCollins
# 6267                  10         6/5/2002                 HarperCollins
# 6270                   2       11/20/2003                        Pocket
# 6271                  55        9/15/1997      Houghton Mifflin Company
# 7512                 171        7/23/2001          Recorded Books  Inc.
# 7513                  12         5/7/2002       HarperCollinsPublishers
# 9151                   4         9/1/1998            Random House Audio

# %% [markdown]
# We see that there are 27 different languages represented by `language_code` in this dataset.

# %%
df.language_code.unique()
# Out:
# array(['eng', 'en-US', 'fre', 'spa', 'en-GB', 'mul', 'grc', 'enm',
#        'en-CA', 'ger', 'jpn', 'ara', 'nl', 'zho', 'lat', 'por', 'srp',
#        'ita', 'rus', 'msa', 'glg', 'wel', 'swe', 'nor', 'tur', 'gla',
#        'ale'], dtype=object)

# %% [markdown]
# Since BigQuery doesn't [support special characters](https://cloud.google.com/bigquery/docs/schemas#column_names) such as `-` as a column name, we clean up the `en-*` entries by replacing the `-` with an underscore.

# %%
df.language_code = df.language_code.str.replace("-","_")

# %% [markdown]
# To feed this into a machine learning model, we want to [one-hot encode](https://en.wikipedia.org/wiki/One-hot) this catagorical column to a set of binary features.

# %%
encoded_df = pd.get_dummies(df, columns=["language_code"])
encoded_df
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                        You Bright and Risen Angels
# 11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                        Poor People
# 11122   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# 1                             J.K. Rowling/Mary GrandPré            4.49
# 2                                           J.K. Rowling            4.42
# 3                             J.K. Rowling/Mary GrandPré            4.56
# 4                             J.K. Rowling/Mary GrandPré            4.78
# ...                                                  ...             ...
# 11118  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 11119                                William T. Vollmann            4.08
# 11120                                William T. Vollmann            3.96
# 11121                                William T. Vollmann            3.72
# 11122                                         Mark Twain            3.91
#
#              isbn         isbn13  num_pages  ratings_count  \
# 0      0439785960  9780439785969        652        2095690
# 1      0439358078  9780439358071        870        2153167
# 2      0439554896  9780439554893        352           6333
# 3      043965548X  9780439655484        435        2339585
# 4      0439682584  9780439682589       2690          41428
# ...           ...            ...        ...            ...
# 11118  1560254416  9781560254416        512            156
# 11119  0140110879  9780140110876        635            783
# 11120  0140131965  9780140131963        415            820
# 11121  0060878827  9780060878825        434            769
# 11122  8497646983  9788497646987        272            113
#
#        text_reviews_count publication_date  ... language_code_nl  \
# 0                   27591        9/16/2006  ...            False
# 1                   29221         9/1/2004  ...            False
# 2                     244        11/1/2003  ...            False
# 3                   36325         5/1/2004  ...            False
# 4                     164        9/13/2004  ...            False
# ...                   ...              ...  ...              ...
# 11118                  20       12/21/2004  ...            False
# 11119                  56        12/1/1988  ...            False
# 11120                  95         8/1/1993  ...            False
# 11121                 139        2/27/2007  ...            False
# 11122                  12        5/28/2006  ...            False
#
#        language_code_nor  language_code_por  language_code_rus  \
# 0                  False              False              False
# 1                  False              False              False
# 2                  False              False              False
# 3                  False              False              False
# 4                  False              False              False
# ...                  ...                ...                ...
# 11118              False              False              False
# 11119              False              False              False
# 11120              False              False              False
# 11121              False              False              False
# 11122              False              False              False
#
#        language_code_spa  language_code_srp  language_code_swe  \
# 0                  False              False              False
# 1                  False              False              False
# 2                  False              False              False
# 3                  False              False              False
# 4                  False              False              False
# ...                  ...                ...                ...
# 11118              False              False              False
# 11119              False              False              False
# 11120              False              False              False
# 11121              False              False              False
# 11122               True              False              False
#
#        language_code_tur  language_code_wel  language_code_zho
# 0                  False              False              False
# 1                  False              False              False
# 2                  False              False              False
# 3                  False              False              False
# 4                  False              False              False
# ...                  ...                ...                ...
# 11118              False              False              False
# 11119              False              False              False
# 11120              False              False              False
# 11121              False              False              False
# 11122              False              False              False
#
# [11123 rows x 38 columns]

# %% [markdown]
# Every single operation that you performed above is being executed directly in your database! The only data that is being pulled out of your database is the few lines of results that is printed in the notebook!

# %% [markdown]
# In this tutorial, we took a look at a quick example of how we can use pandas to work with the data directly in your database. Next, we will take a look at the different ways you can [work with a data source in Ponder](https://docs.ponder.io/getting_started/reading.html). If you are looking to learn more about how you can use Ponder, check out [this tutorial series](https://app.ponder.io/resources).
