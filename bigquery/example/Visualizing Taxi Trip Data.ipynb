# %% [markdown]
# # Visualizing Data with BigQuery using Ponder

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>Before we get started: </b>
#     <ul style="list-style-type: none;margin: 0;padding: 0;">
#         <li>✍️ To run this notebook, you need to have Ponder installed and set up on your machine. If you have not done so already, please refer to our <a href="https://docs.ponder.io/getting_started/quickstart.html">Quickstart guide</a> to get started.</li>
#         <li>📖 Otherwise, if you're just interested in browsing through the notebook, keep reading below!</li>
#     </ul>
# </div>

# %% [markdown]
# Data visualization is a key component of exploratory data analysis that is useful for data cleaning, identifying outliers and feature relationships, and so on. Interactive Python libraries like Matplotlib or Seaborn allow data scientists to draw fast insights, but when the data is stored in a cloud data warehouse such as BigQuery this is not possible.

# %% [markdown]
# ## Why use Ponder?

# %% [markdown]
# Usually such a task would require exporting the data to CSV or Google Sheets and using BI tools like Looker or Tableau. Ponder changes this by enabling users to run pandas directly in the data warehouse! In this post, we’ll walk through an example that will explore a dataset through various visualizations. To learn more about Ponder, check out our [recent blogpost](https://ponder.io/run-pandas-on-1tb-directly-in-your-data-warehouse/) and [sign up here](https://ponder.io/product/) to try it out today.

# %% [markdown]
# ## Visualizing the NYC Yellow Taxi Dataset

# %% [markdown]
# Our dataset is from a sample of NYC Yellow Taxi trip records on January 1st, 2015. We store this data in a Google BigQuery table and perform data transformations and visualizations using Matplotlib directly from this datastore.
#
# The NYC Yellow Taxi dataset contains information regarding trips taken by passengers, including dropoff and pickup times, passenger count, tip amount, and total ride cost.

# %% [markdown]
# ### Connecting to BigQuery
# To start querying our data, we need to set up our BigQuery connection.

# %%
import modin.pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import ponder
ponder.init()
# Out:
# 2023-05-16 16:19:29 - Creating session fuF3blxEOeDzXCe5rV5rSGB5h8LzX4T7fOhLpaKkQM

# %%
from google.cloud import bigquery
from google.cloud.bigquery import dbapi
from google.oauth2 import service_account
import json

bigquery_con = dbapi.Connection(
            bigquery.Client(
            credentials=service_account.Credentials.from_service_account_info(
                    json.loads(open("../credential.json").read()),
                    scopes=["https://www.googleapis.com/auth/bigquery"],
                )
            )
        )

ponder.configure(bigquery_dataset='PONDER', default_connection=bigquery_con)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ponder-org/ponder-datasets/main/yellow_tripdata_2015-01.csv", header=0)

# %%
df = df[df['PASSENGER_COUNT']>0]
df = df.drop(columns=['CONGESTION_SURCHARGE','AIRPORT_FEE'])
# Out:
# UserWarning: Switching away from database execution mode. A limited sample of 10000 rows was loaded into memory for local execution. To change this limit, run ponder.configure(row_transfer_limit=X) with a different value.

# %% [markdown]
# ### Let's investigate the tip amounts. How much do people tip percentage wise based on their total charge?

# %%
df2 = df.loc[df['TIP_AMOUNT']>0] 

fig, ax = plt.subplots()
plt.figure(figsize=(15, 3))
ax.hist(df2['TIP_AMOUNT']*100.0/df2['TOTAL_AMOUNT'], bins=100)
ax.set_title("Distribution of Tip Percentage")
ax.set_ylabel('Count')
ax.set_xlabel('% Tipped')
plt.show()

# %% [markdown]
# #### Here we see that most people tip 15-18% of their total taxi ride amount. We make sure to not include tip amounts equal to 0 as those would result in a zero division error.
#
# #### Now let’s find the proportion of the number of passengers taking taxi rides. Pie charts are not that popular these days, but in honor of Pie Day just passing we feel obliged to include one.

# %%
df_passcount = df.groupby(['PASSENGER_COUNT']).count()['VENDORID']
df_passcount
# Out:
# PASSENGER_COUNT
# 1    9587
# 2    2724
# 3     880
# 4     492
# 5     831
# 6     485
# Name: VENDORID, dtype: Int64

# %%
x = df_passcount
colors = plt.get_cmap('Blues')(np.linspace(0.3, 0.9, len(x)))

fig, ax = plt.subplots()
ax.pie(x, labels=df_passcount.index, colors=colors, 
       wedgeprops={"linewidth": 1, "edgecolor": "white"})

ax.set_title("Taxi Rides Passenger Count")
plt.show()

# %% [markdown]
# #### Interestingly, there are more solo rides than those with 2 passengers. Perhaps this is contributing to the NYC road congestion? Also, it looks like there are fewer trips with 4 riders than rides in a 5 seater taxi (or a 6 riders with legally assumes a child under 7 years is in a 5 seater taxi).
#
# #### We can also see how the fare amounts change throughout the day based on the dropoff times.

# %%
import matplotlib.dates as mdates

dropoff = pd.to_datetime(df.TPEP_DROPOFF_DATETIME)
plt.figure(figsize=(150, 5))
fig, ax = plt.subplots()
plt.xticks(rotation=30)

ax.set_xlabel('Dropoff Time')
ax.set_ylabel('Fare Amount')

ax.scatter(dropoff, df.FARE_AMOUNT, s=4)
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py", line 114, in run_query_and_return_results
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py", line 1520, in result
#     do_get_result()
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/google/api_core/retry.py", line 349, in retry_wrapped_func
#     return retry_target(
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/google/api_core/retry.py", line 191, in retry_target
#     return target()
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py", line 1510, in do_get_result
#     super(QueryJob, self).result(retry=retry, timeout=timeout)
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/google/cloud/bigquery/job/base.py", line 911, in result
#     return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/google/api_core/future/polling.py", line 261, in result
#     raise self._exception
# google.api_core.exceptions.BadRequest: 400 Syntax error: Expected ")" but got ":" at [7:34]
#
# Location: US
# Job ID: f98b80da-9061-494d-a4c0-7ecbd950585a
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py", line 152, in _run_query_and_return_dataframe_uncached
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py", line 120, in run_query_and_return_results
# RuntimeError: Error in
#             SELECT
#                 _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME
#             FROM (
#
#         SELECT
#             TPEP_DROPOFF_DATETIME::DATETIME AS TPEP_DROPOFF_DATETIME, _PONDER_ROW_LABELS_, _PONDER_ROW_NUMBER_
#         FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,CONGESTION_SURCHARGE,AIRPORT_FEE,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_NUMBER_ AS _PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT, CONGESTION_SURCHARGE, AIRPORT_FEE, _PONDER_ROW_NUMBER_, _PONDER_ROW_NUMBER_
#                         AS _PONDER_ROW_LABELS_ FROM PONDER.PONDER_LTBXQQJDEA
#             )
#             WHERE
#                 IFNULL((PASSENGER_COUNT  )>0, FALSE)
#             )
#             )))
#
#             )
#             ORDER BY _PONDER_ROW_NUMBER_
#             LIMIT 10001 because 400 Syntax error: Expected ")" but got ":" at [7:34]
#
# Location: US
# Job ID: f98b80da-9061-494d-a4c0-7ecbd950585a
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/query_compiler.py", line 420, in to_pandas
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/dataframe.py", line 183, in to_pandas
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/query_tree.py", line 1107, in to_pandas
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py", line 280, in to_pandas
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/sql_connection.py", line 95, in run_query_and_return_dataframe
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/common.py", line 308, in wrapper
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/sql_connection.py", line 105, in _run_query_and_return_dataframe_cached
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py", line 156, in _run_query_and_return_dataframe_uncached
# RuntimeError: Error in getting table metadata
#             SELECT
#                 _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME
#             FROM (
#
#         SELECT
#             TPEP_DROPOFF_DATETIME::DATETIME AS TPEP_DROPOFF_DATETIME, _PONDER_ROW_LABELS_, _PONDER_ROW_NUMBER_
#         FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,CONGESTION_SURCHARGE,AIRPORT_FEE,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_NUMBER_ AS _PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT, CONGESTION_SURCHARGE, AIRPORT_FEE, _PONDER_ROW_NUMBER_, _PONDER_ROW_NUMBER_
#                         AS _PONDER_ROW_LABELS_ FROM PONDER.PONDER_LTBXQQJDEA
#             )
#             WHERE
#                 IFNULL((PASSENGER_COUNT  )>0, FALSE)
#             )
#             )))
#
#             )
#             ORDER BY _PONDER_ROW_NUMBER_
#             LIMIT 10001 because Error in
#             SELECT
#                 _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME
#             FROM (
#
#         SELECT
#             TPEP_DROPOFF_DATETIME::DATETIME AS TPEP_DROPOFF_DATETIME, _PONDER_ROW_LABELS_, _PONDER_ROW_NUMBER_
#         FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,CONGESTION_SURCHARGE,AIRPORT_FEE,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_NUMBER_ AS _PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT, CONGESTION_SURCHARGE, AIRPORT_FEE, _PONDER_ROW_NUMBER_, _PONDER_ROW_NUMBER_
#                         AS _PONDER_ROW_LABELS_ FROM PONDER.PONDER_LTBXQQJDEA
#             )
#             WHERE
#                 IFNULL((PASSENGER_COUNT  )>0, FALSE)
#             )
#             )))
#
#             )
#             ORDER BY _PONDER_ROW_NUMBER_
#             LIMIT 10001 because 400 Syntax error: Expected ")" but got ":" at [7:34]
#
# Location: US
# Job ID: f98b80da-9061-494d-a4c0-7ecbd950585a
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py:114, in run_query_and_return_results(self, query)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1520, in QueryJob.result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1518         do_get_result = job_retry(do_get_result)
# -> 1520     do_get_result()
#    1522 except exceptions.GoogleAPICallError as exc:
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/google/api_core/retry.py:349, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     346 sleep_generator = exponential_sleep_generator(
#     347     self._initial, self._maximum, multiplier=self._multiplier
#     348 )
# --> 349 return retry_target(
#     350     target,
#     351     self._predicate,
#     352     sleep_generator,
#     353     self._timeout,
#     354     on_error=on_error,
#     355 )
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/google/api_core/retry.py:191, in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     190 try:
# --> 191     return target()
#     193 # pylint: disable=broad-except
#     194 # This function explicitly must deal with broad exceptions.
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1510, in QueryJob.result.<locals>.do_get_result()
#    1508     self._job_retry = job_retry
# -> 1510 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1512 # Since the job could already be "done" (e.g. got a finished job
#    1513 # via client.get_job), the superclass call to done() might not
#    1514 # set the self._query_results cache.
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/google/cloud/bigquery/job/base.py:911, in _AsyncJob.result(self, retry, timeout)
#     910 kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 911 return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/google/api_core/future/polling.py:261, in PollingFuture.result(self, timeout, retry, polling)
#     258 if self._exception is not None:
#     259     # pylint: disable=raising-bad-type
#     260     # Pylint doesn't recognize that this is valid in this case.
# --> 261     raise self._exception
#     263 return self._result
#
# BadRequest: 400 Syntax error: Expected ")" but got ":" at [7:34]
#
# Location: US
# Job ID: f98b80da-9061-494d-a4c0-7ecbd950585a
#
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py:152, in _run_query_and_return_dataframe_uncached(self, query)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py:120, in run_query_and_return_results(self, query)
#
# RuntimeError: Error in
#             SELECT
#                 _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME
#             FROM (
#
#         SELECT
#             TPEP_DROPOFF_DATETIME::DATETIME AS TPEP_DROPOFF_DATETIME, _PONDER_ROW_LABELS_, _PONDER_ROW_NUMBER_
#         FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,CONGESTION_SURCHARGE,AIRPORT_FEE,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_NUMBER_ AS _PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT, CONGESTION_SURCHARGE, AIRPORT_FEE, _PONDER_ROW_NUMBER_, _PONDER_ROW_NUMBER_
#                         AS _PONDER_ROW_LABELS_ FROM PONDER.PONDER_LTBXQQJDEA
#             )
#             WHERE
#                 IFNULL((PASSENGER_COUNT  )>0, FALSE)
#             )
#             )))
#
#             )
#             ORDER BY _PONDER_ROW_NUMBER_
#             LIMIT 10001 because 400 Syntax error: Expected ")" but got ":" at [7:34]
#
# Location: US
# Job ID: f98b80da-9061-494d-a4c0-7ecbd950585a
#
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Input In [9], in <cell line: 11>()
#       8 ax.set_xlabel('Dropoff Time')
#       9 ax.set_ylabel('Fare Amount')
# ---> 11 ax.scatter(dropoff, df.FARE_AMOUNT, s=4)
#      12 plt.show()
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4578, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4468 """
#    4469 A scatter plot of *y* vs. *x* with varying marker size and/or color.
#    4470
#    (...)
#    4575
#    4576 """
#    4577 # Process **kwargs to handle aliases, conflicts with explicit kwargs:
# -> 4578 x, y = self._process_unit_info([("x", x), ("y", y)], kwargs)
#    4579 # np.ma.ravel yields an ndarray, not a masked array,
#    4580 # unless its argument is a masked array.
#    4581 x = np.ma.ravel(x)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/matplotlib/axes/_base.py:2549, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2547     # Update from data if axis is already set but no unit is set yet.
#    2548     if axis is not None and data is not None and not axis.have_units():
# -> 2549         axis.update_units(data)
#    2550 for axis_name, axis in axis_map.items():
#    2551     # Return if no axis is set.
#    2552     if axis is None:
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/matplotlib/axis.py:1669, in Axis.update_units(self, data)
#    1663 def update_units(self, data):
#    1664     """
#    1665     Introspect *data* for units converter and update the
#    1666     ``axis.converter`` instance if necessary. Return *True*
#    1667     if *data* is registered for unit conversion.
#    1668     """
# -> 1669     converter = munits.registry.get_converter(data)
#    1670     if converter is None:
#    1671         return False
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/matplotlib/units.py:167, in Registry.get_converter(self, x)
#     165 """Get the converter interface instance for *x*, or None."""
#     166 # Unpack in case of e.g. Pandas or xarray object
# --> 167 x = cbook._unpack_to_numpy(x)
#     169 if isinstance(x, np.ndarray):
#     170     # In case x in a masked array, access the underlying data (only its
#     171     # type matters).  If x is a regular ndarray, getdata() just returns
#     172     # the array itself.
#     173     x = np.ma.getdata(x).ravel()
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:2297, in _unpack_to_numpy(x)
#    2294     return x
#    2295 if hasattr(x, 'to_numpy'):
#    2296     # Assume that any function to_numpy() do actually return a numpy array
# -> 2297     return x.to_numpy()
#    2298 if hasattr(x, 'values'):
#    2299     xtmp = x.values
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/modin/pandas/series.py:1927, in Series.to_numpy(self, dtype, copy, na_value, **kwargs)
#    1923 from modin.config import ExperimentalNumPyAPI
#    1925 if not ExperimentalNumPyAPI.get():
#    1926     return (
# -> 1927         super(Series, self)
#    1928         .to_numpy(
#    1929             dtype=dtype,
#    1930             copy=copy,
#    1931             na_value=na_value,
#    1932         )
#    1933         .flatten()
#    1934     )
#    1935 else:
#    1936     from ..numpy.arr import array
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/modin/pandas/base.py:3212, in BasePandasDataset.to_numpy(self, dtype, copy, na_value)
#    3208     from ..numpy.arr import array
#    3210     return array(self, copy=copy)
# -> 3212 return self._query_compiler.to_numpy(
#    3213     dtype=dtype,
#    3214     copy=copy,
#    3215     na_value=na_value,
#    3216 )
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/query_compiler.py:442, in to_numpy(self, **kwargs)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/query_compiler.py:420, in to_pandas(self)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/dataframe.py:183, in to_pandas(self)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/query_tree.py:1107, in to_pandas(self)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py:280, in to_pandas(self, tree_node)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/sql_connection.py:95, in run_query_and_return_dataframe(self, query, use_cache)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/common.py:308, in wrapper(*args, **kwargs)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/sql_connection.py:105, in _run_query_and_return_dataframe_cached(self, query)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py:156, in _run_query_and_return_dataframe_uncached(self, query)
#
# RuntimeError: Error in getting table metadata
#             SELECT
#                 _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME
#             FROM (
#
#         SELECT
#             TPEP_DROPOFF_DATETIME::DATETIME AS TPEP_DROPOFF_DATETIME, _PONDER_ROW_LABELS_, _PONDER_ROW_NUMBER_
#         FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,CONGESTION_SURCHARGE,AIRPORT_FEE,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_NUMBER_ AS _PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT, CONGESTION_SURCHARGE, AIRPORT_FEE, _PONDER_ROW_NUMBER_, _PONDER_ROW_NUMBER_
#                         AS _PONDER_ROW_LABELS_ FROM PONDER.PONDER_LTBXQQJDEA
#             )
#             WHERE
#                 IFNULL((PASSENGER_COUNT  )>0, FALSE)
#             )
#             )))
#
#             )
#             ORDER BY _PONDER_ROW_NUMBER_
#             LIMIT 10001 because Error in
#             SELECT
#                 _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME
#             FROM (
#
#         SELECT
#             TPEP_DROPOFF_DATETIME::DATETIME AS TPEP_DROPOFF_DATETIME, _PONDER_ROW_LABELS_, _PONDER_ROW_NUMBER_
#         FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,CONGESTION_SURCHARGE,AIRPORT_FEE,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_NUMBER_ AS _PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT, CONGESTION_SURCHARGE, AIRPORT_FEE, _PONDER_ROW_NUMBER_, _PONDER_ROW_NUMBER_
#                         AS _PONDER_ROW_LABELS_ FROM PONDER.PONDER_LTBXQQJDEA
#             )
#             WHERE
#                 IFNULL((PASSENGER_COUNT  )>0, FALSE)
#             )
#             )))
#
#             )
#             ORDER BY _PONDER_ROW_NUMBER_
#             LIMIT 10001 because 400 Syntax error: Expected ")" but got ":" at [7:34]
#
# Location: US
# Job ID: f98b80da-9061-494d-a4c0-7ecbd950585a

# %% [markdown]
# #### Are those negative fare values? This shouldn’t be possible, so let’s clean our data and regenerate this visualization.

# %%
df = df[df['FARE_AMOUNT']>=0]

dropoff = pd.to_datetime(df.TPEP_DROPOFF_DATETIME)
plt.figure(figsize=(150, 5))
fig, ax = plt.subplots()
plt.xticks(rotation=30)

ax.set_xlabel('Dropoff Time')
ax.set_ylabel('Fare Amount')

ax.scatter(dropoff, df.FARE_AMOUNT, s=4)
plt.show()
# Out:
# UserWarning: Switching away from database execution mode. A limited sample of 10000 rows was loaded into memory for local execution. To change this limit, run ponder.configure(row_transfer_limit=X) with a different value.
# Traceback (most recent call last):
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py", line 114, in run_query_and_return_results
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py", line 1520, in result
#     do_get_result()
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/google/api_core/retry.py", line 349, in retry_wrapped_func
#     return retry_target(
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/google/api_core/retry.py", line 191, in retry_target
#     return target()
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py", line 1510, in do_get_result
#     super(QueryJob, self).result(retry=retry, timeout=timeout)
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/google/cloud/bigquery/job/base.py", line 911, in result
#     return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/google/api_core/future/polling.py", line 261, in result
#     raise self._exception
# google.api_core.exceptions.BadRequest: 400 Syntax error: Expected ")" but got ":" at [7:34]
#
# Location: US
# Job ID: afc64b9f-fdf0-494a-b1b7-af156a05da3a
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py", line 152, in _run_query_and_return_dataframe_uncached
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py", line 120, in run_query_and_return_results
# RuntimeError: Error in
#             SELECT
#                 _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME
#             FROM (
#
#         SELECT
#             TPEP_DROPOFF_DATETIME::DATETIME AS TPEP_DROPOFF_DATETIME, _PONDER_ROW_LABELS_, _PONDER_ROW_NUMBER_
#         FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,CONGESTION_SURCHARGE,AIRPORT_FEE,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_NUMBER_ AS _PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT, CONGESTION_SURCHARGE, AIRPORT_FEE, _PONDER_ROW_NUMBER_, _PONDER_ROW_NUMBER_
#                         AS _PONDER_ROW_LABELS_ FROM PONDER.PONDER_LTBXQQJDEA
#             )
#             WHERE
#                 IFNULL((PASSENGER_COUNT  )>0, FALSE)
#             )
#             )
#             )
#             WHERE
#                 IFNULL((FARE_AMOUNT  )>=0, FALSE)
#             )
#             ))
#
#             )
#             ORDER BY _PONDER_ROW_NUMBER_
#             LIMIT 10001 because 400 Syntax error: Expected ")" but got ":" at [7:34]
#
# Location: US
# Job ID: afc64b9f-fdf0-494a-b1b7-af156a05da3a
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/query_compiler.py", line 420, in to_pandas
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/dataframe.py", line 183, in to_pandas
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/query_tree.py", line 1107, in to_pandas
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py", line 280, in to_pandas
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/sql_connection.py", line 95, in run_query_and_return_dataframe
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/common.py", line 308, in wrapper
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/sql_connection.py", line 105, in _run_query_and_return_dataframe_cached
#   File "/Users/dorislee/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py", line 156, in _run_query_and_return_dataframe_uncached
# RuntimeError: Error in getting table metadata
#             SELECT
#                 _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME
#             FROM (
#
#         SELECT
#             TPEP_DROPOFF_DATETIME::DATETIME AS TPEP_DROPOFF_DATETIME, _PONDER_ROW_LABELS_, _PONDER_ROW_NUMBER_
#         FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,CONGESTION_SURCHARGE,AIRPORT_FEE,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_NUMBER_ AS _PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT, CONGESTION_SURCHARGE, AIRPORT_FEE, _PONDER_ROW_NUMBER_, _PONDER_ROW_NUMBER_
#                         AS _PONDER_ROW_LABELS_ FROM PONDER.PONDER_LTBXQQJDEA
#             )
#             WHERE
#                 IFNULL((PASSENGER_COUNT  )>0, FALSE)
#             )
#             )
#             )
#             WHERE
#                 IFNULL((FARE_AMOUNT  )>=0, FALSE)
#             )
#             ))
#
#             )
#             ORDER BY _PONDER_ROW_NUMBER_
#             LIMIT 10001 because Error in
#             SELECT
#                 _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME
#             FROM (
#
#         SELECT
#             TPEP_DROPOFF_DATETIME::DATETIME AS TPEP_DROPOFF_DATETIME, _PONDER_ROW_LABELS_, _PONDER_ROW_NUMBER_
#         FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,CONGESTION_SURCHARGE,AIRPORT_FEE,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_NUMBER_ AS _PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT, CONGESTION_SURCHARGE, AIRPORT_FEE, _PONDER_ROW_NUMBER_, _PONDER_ROW_NUMBER_
#                         AS _PONDER_ROW_LABELS_ FROM PONDER.PONDER_LTBXQQJDEA
#             )
#             WHERE
#                 IFNULL((PASSENGER_COUNT  )>0, FALSE)
#             )
#             )
#             )
#             WHERE
#                 IFNULL((FARE_AMOUNT  )>=0, FALSE)
#             )
#             ))
#
#             )
#             ORDER BY _PONDER_ROW_NUMBER_
#             LIMIT 10001 because 400 Syntax error: Expected ")" but got ":" at [7:34]
#
# Location: US
# Job ID: afc64b9f-fdf0-494a-b1b7-af156a05da3a
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py:114, in run_query_and_return_results(self, query)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1520, in QueryJob.result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1518         do_get_result = job_retry(do_get_result)
# -> 1520     do_get_result()
#    1522 except exceptions.GoogleAPICallError as exc:
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/google/api_core/retry.py:349, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     346 sleep_generator = exponential_sleep_generator(
#     347     self._initial, self._maximum, multiplier=self._multiplier
#     348 )
# --> 349 return retry_target(
#     350     target,
#     351     self._predicate,
#     352     sleep_generator,
#     353     self._timeout,
#     354     on_error=on_error,
#     355 )
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/google/api_core/retry.py:191, in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     190 try:
# --> 191     return target()
#     193 # pylint: disable=broad-except
#     194 # This function explicitly must deal with broad exceptions.
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1510, in QueryJob.result.<locals>.do_get_result()
#    1508     self._job_retry = job_retry
# -> 1510 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1512 # Since the job could already be "done" (e.g. got a finished job
#    1513 # via client.get_job), the superclass call to done() might not
#    1514 # set the self._query_results cache.
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/google/cloud/bigquery/job/base.py:911, in _AsyncJob.result(self, retry, timeout)
#     910 kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 911 return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/google/api_core/future/polling.py:261, in PollingFuture.result(self, timeout, retry, polling)
#     258 if self._exception is not None:
#     259     # pylint: disable=raising-bad-type
#     260     # Pylint doesn't recognize that this is valid in this case.
# --> 261     raise self._exception
#     263 return self._result
#
# BadRequest: 400 Syntax error: Expected ")" but got ":" at [7:34]
#
# Location: US
# Job ID: afc64b9f-fdf0-494a-b1b7-af156a05da3a
#
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py:152, in _run_query_and_return_dataframe_uncached(self, query)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py:120, in run_query_and_return_results(self, query)
#
# RuntimeError: Error in
#             SELECT
#                 _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME
#             FROM (
#
#         SELECT
#             TPEP_DROPOFF_DATETIME::DATETIME AS TPEP_DROPOFF_DATETIME, _PONDER_ROW_LABELS_, _PONDER_ROW_NUMBER_
#         FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,CONGESTION_SURCHARGE,AIRPORT_FEE,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_NUMBER_ AS _PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT, CONGESTION_SURCHARGE, AIRPORT_FEE, _PONDER_ROW_NUMBER_, _PONDER_ROW_NUMBER_
#                         AS _PONDER_ROW_LABELS_ FROM PONDER.PONDER_LTBXQQJDEA
#             )
#             WHERE
#                 IFNULL((PASSENGER_COUNT  )>0, FALSE)
#             )
#             )
#             )
#             WHERE
#                 IFNULL((FARE_AMOUNT  )>=0, FALSE)
#             )
#             ))
#
#             )
#             ORDER BY _PONDER_ROW_NUMBER_
#             LIMIT 10001 because 400 Syntax error: Expected ")" but got ":" at [7:34]
#
# Location: US
# Job ID: afc64b9f-fdf0-494a-b1b7-af156a05da3a
#
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Input In [10], in <cell line: 11>()
#       8 ax.set_xlabel('Dropoff Time')
#       9 ax.set_ylabel('Fare Amount')
# ---> 11 ax.scatter(dropoff, df.FARE_AMOUNT, s=4)
#      12 plt.show()
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4578, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4468 """
#    4469 A scatter plot of *y* vs. *x* with varying marker size and/or color.
#    4470
#    (...)
#    4575
#    4576 """
#    4577 # Process **kwargs to handle aliases, conflicts with explicit kwargs:
# -> 4578 x, y = self._process_unit_info([("x", x), ("y", y)], kwargs)
#    4579 # np.ma.ravel yields an ndarray, not a masked array,
#    4580 # unless its argument is a masked array.
#    4581 x = np.ma.ravel(x)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/matplotlib/axes/_base.py:2549, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2547     # Update from data if axis is already set but no unit is set yet.
#    2548     if axis is not None and data is not None and not axis.have_units():
# -> 2549         axis.update_units(data)
#    2550 for axis_name, axis in axis_map.items():
#    2551     # Return if no axis is set.
#    2552     if axis is None:
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/matplotlib/axis.py:1669, in Axis.update_units(self, data)
#    1663 def update_units(self, data):
#    1664     """
#    1665     Introspect *data* for units converter and update the
#    1666     ``axis.converter`` instance if necessary. Return *True*
#    1667     if *data* is registered for unit conversion.
#    1668     """
# -> 1669     converter = munits.registry.get_converter(data)
#    1670     if converter is None:
#    1671         return False
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/matplotlib/units.py:167, in Registry.get_converter(self, x)
#     165 """Get the converter interface instance for *x*, or None."""
#     166 # Unpack in case of e.g. Pandas or xarray object
# --> 167 x = cbook._unpack_to_numpy(x)
#     169 if isinstance(x, np.ndarray):
#     170     # In case x in a masked array, access the underlying data (only its
#     171     # type matters).  If x is a regular ndarray, getdata() just returns
#     172     # the array itself.
#     173     x = np.ma.getdata(x).ravel()
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:2297, in _unpack_to_numpy(x)
#    2294     return x
#    2295 if hasattr(x, 'to_numpy'):
#    2296     # Assume that any function to_numpy() do actually return a numpy array
# -> 2297     return x.to_numpy()
#    2298 if hasattr(x, 'values'):
#    2299     xtmp = x.values
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/modin/pandas/series.py:1927, in Series.to_numpy(self, dtype, copy, na_value, **kwargs)
#    1923 from modin.config import ExperimentalNumPyAPI
#    1925 if not ExperimentalNumPyAPI.get():
#    1926     return (
# -> 1927         super(Series, self)
#    1928         .to_numpy(
#    1929             dtype=dtype,
#    1930             copy=copy,
#    1931             na_value=na_value,
#    1932         )
#    1933         .flatten()
#    1934     )
#    1935 else:
#    1936     from ..numpy.arr import array
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/modin/pandas/base.py:3212, in BasePandasDataset.to_numpy(self, dtype, copy, na_value)
#    3208     from ..numpy.arr import array
#    3210     return array(self, copy=copy)
# -> 3212 return self._query_compiler.to_numpy(
#    3213     dtype=dtype,
#    3214     copy=copy,
#    3215     na_value=na_value,
#    3216 )
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/query_compiler.py:442, in to_numpy(self, **kwargs)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/query_compiler.py:420, in to_pandas(self)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/dataframe.py:183, in to_pandas(self)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/query_tree.py:1107, in to_pandas(self)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py:280, in to_pandas(self, tree_node)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/sql_connection.py:95, in run_query_and_return_dataframe(self, query, use_cache)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/common.py:308, in wrapper(*args, **kwargs)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/common/sql_connection.py:105, in _run_query_and_return_dataframe_cached(self, query)
#
# File ~/.virtualenvs/dev/lib/python3.10/site-packages/ponder/pushdown_service/bigquery/connection.py:156, in _run_query_and_return_dataframe_uncached(self, query)
#
# RuntimeError: Error in getting table metadata
#             SELECT
#                 _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME
#             FROM (
#
#         SELECT
#             TPEP_DROPOFF_DATETIME::DATETIME AS TPEP_DROPOFF_DATETIME, _PONDER_ROW_LABELS_, _PONDER_ROW_NUMBER_
#         FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,CONGESTION_SURCHARGE,AIRPORT_FEE,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_NUMBER_ AS _PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT, CONGESTION_SURCHARGE, AIRPORT_FEE, _PONDER_ROW_NUMBER_, _PONDER_ROW_NUMBER_
#                         AS _PONDER_ROW_LABELS_ FROM PONDER.PONDER_LTBXQQJDEA
#             )
#             WHERE
#                 IFNULL((PASSENGER_COUNT  )>0, FALSE)
#             )
#             )
#             )
#             WHERE
#                 IFNULL((FARE_AMOUNT  )>=0, FALSE)
#             )
#             ))
#
#             )
#             ORDER BY _PONDER_ROW_NUMBER_
#             LIMIT 10001 because Error in
#             SELECT
#                 _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME
#             FROM (
#
#         SELECT
#             TPEP_DROPOFF_DATETIME::DATETIME AS TPEP_DROPOFF_DATETIME, _PONDER_ROW_LABELS_, _PONDER_ROW_NUMBER_
#         FROM (SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, TPEP_DROPOFF_DATETIME FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT _PONDER_ROW_NUMBER_, _PONDER_ROW_LABELS_, VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT FROM (
#             SELECT
#                 VENDORID,TPEP_PICKUP_DATETIME,TPEP_DROPOFF_DATETIME,PASSENGER_COUNT,TRIP_DISTANCE,RATECODEID,STORE_AND_FWD_FLAG,PULOCATIONID,DOLOCATIONID,PAYMENT_TYPE,FARE_AMOUNT,EXTRA,MTA_TAX,TIP_AMOUNT,TOLLS_AMOUNT,IMPROVEMENT_SURCHARGE,TOTAL_AMOUNT,CONGESTION_SURCHARGE,AIRPORT_FEE,
#             ROW_NUMBER()
#             OVER (
#                 ORDER BY _PONDER_ROW_NUMBER_
#             ) -1 AS _PONDER_ROW_NUMBER_
#             ,_PONDER_ROW_NUMBER_ AS _PONDER_ROW_LABELS_
#             FROM (
#
#             SELECT *
#             FROM (
#                 SELECT VENDORID, TPEP_PICKUP_DATETIME, TPEP_DROPOFF_DATETIME, PASSENGER_COUNT, TRIP_DISTANCE, RATECODEID, STORE_AND_FWD_FLAG, PULOCATIONID, DOLOCATIONID, PAYMENT_TYPE, FARE_AMOUNT, EXTRA, MTA_TAX, TIP_AMOUNT, TOLLS_AMOUNT, IMPROVEMENT_SURCHARGE, TOTAL_AMOUNT, CONGESTION_SURCHARGE, AIRPORT_FEE, _PONDER_ROW_NUMBER_, _PONDER_ROW_NUMBER_
#                         AS _PONDER_ROW_LABELS_ FROM PONDER.PONDER_LTBXQQJDEA
#             )
#             WHERE
#                 IFNULL((PASSENGER_COUNT  )>0, FALSE)
#             )
#             )
#             )
#             WHERE
#                 IFNULL((FARE_AMOUNT  )>=0, FALSE)
#             )
#             ))
#
#             )
#             ORDER BY _PONDER_ROW_NUMBER_
#             LIMIT 10001 because 400 Syntax error: Expected ")" but got ":" at [7:34]
#
# Location: US
# Job ID: afc64b9f-fdf0-494a-b1b7-af156a05da3a

# %% [markdown]
# #### That was fairly simple! We notice that the fares are higher with taxi drop off times closer to 12 AM. The sharp gap shows that there are much fewer trips made past 3 PM and rides pick up again towards midnight. This however reflects the sample of records taken from January 1st, 2015 rather than rider behavior.
#
# #### Also, let’s take a moment to reflect on how straightforward it was to convert the TPEP_DROPOFF_DATETIME column to pandas datetime which Matplotlib can use to plot time series data out of the box.
#
# #### How does the number of passengers impact trip cost features?

# %%
df_pass_tip_fare = df.groupby('PASSENGER_COUNT').mean()[['FARE_AMOUNT', 'TIP_AMOUNT','TOLLS_AMOUNT', 'TOTAL_AMOUNT']].reset_index()

# %%
x = df_pass_tip_fare.PASSENGER_COUNT
y = {
    "Tolls": df_pass_tip_fare.TOLLS_AMOUNT.to_numpy(),
    "Tip": df_pass_tip_fare.TIP_AMOUNT.to_numpy(),
    "Fare": df_pass_tip_fare.FARE_AMOUNT.to_numpy(),
    "Total": df_pass_tip_fare.TOTAL_AMOUNT.to_numpy(),
}
width = 0.2  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in y.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

ax.set_title("Comparing Trip Cost Across Number of Passengers")
ax.set_xlabel('Passenger Count')
ax.set_ylabel('Amount ($)')

ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 20)

plt.show()

# %% [markdown]
# #### We see that overall taxi costs are fairly uniform across passenger count. Since taxi fares are based on meters that calculate trip distance and time, this makes sense!
#
# #### To find out if trip distance affects tip amounts, we can use hexagonal binning to plot density efficiently.

# %%
df_dist_less_30 = df[df["TRIP_DISTANCE"]<30]

x = df_dist_less_30.TRIP_DISTANCE
y = df_dist_less_30.TIP_AMOUNT

# %%
fig, ax = plt.subplots()

hb = ax.hexbin(x, y, cmap='inferno')

ax.set(xlim=(0, 15), ylim=(0, 6))
ax.set_xlabel('Trip Distance')
ax.set_ylabel('Tip Amount($)')
ax.set_title("Hexagon binning")
cb = fig.colorbar(hb, ax=ax, label='counts')
plt.show()

# %% [markdown]
# #### From this visualization, we see that while the tip amount generally increases with distance, the relationship is non-linear. There is also a significant occurrence of the tip remaining below $1 as distance increases. However, we must consider that this may not fully reflect NYC riders’ tipping behaviors as cash tips were not included in this dataset.

# %% [markdown]
# ## Summary

# %% [markdown]
# In this post, we saw how easy it is to visualize data in your data warehouse using Ponder without needing to export data to any other format. All the pandas operations were running directly in BigQuery and we used Matplotlib to generate visualizations to iterate on findings. When irregularities were found, we could quickly clean our data using vanilla pandas and regenerate plots accordingly. No longer do users have to rerun SQL queries, download their data as a CSV file or Google Sheets, and connect to BI tools for exploratory data analysis.
#
# Interested in trying this out for yourself? Sign up [here](http://ponder.io/product) to get started in using Ponder!
